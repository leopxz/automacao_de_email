# %% [markdown]
# # Projeto 02
#
# - Buscar as info da ação automaticamente
# - Criar analise
#     .cotação maxima
#     .cotação minima
#     .Valor medio
#
# - enviar um e-mail automaticamente para o gestor

# %% [markdown]
# ### Buscar dados da ação automaticamente
#
# Biblioteca: `yfinance` e `matplotlib`

# %% [markdown]
# ### Importando a yfinance
# ```import yfinance```

# %%
import yfinance

# %%
acao = input("Digite o codigo da ação desejada: ")

dados = yfinance.Ticker(acao).history(start="2020-01-01", end="2020-12-31")
fechamento = dados.Open
fechamento.plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: xlabel='Date'>
